# %% [markdown]
# <a href="https://colab.research.google.com/github/QuratAkhter/GenAI/blob/main/GenAI_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('IMDB Dataset.csv')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df = df.head(200)

# %% [markdown]
# ## Lower Case

# %%
df['review'] = df['review'].str.lower()

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ## Remove HTML tags

# %%
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
text = '<h>Hello I am <b>Qurat</b></h>'
remove_html_tags(text)
# Out:
# 'Hello I am Qurat'

# %%
df['review'] = df['review'].apply(remove_html_tags)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. the filming tec...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ## Remove URL

# %%
def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r"",text)

# %%
text = 'My linkedin URL is https://www.linkedin.com/qurat_akhter'
remove_url(text)
# Out:
# 'My linkedin URL is '

# %%
df['review'] = df['review'].apply(remove_url)

# %% [markdown]
# ## Punctuation Handling

# %%
import string
exclude = string.punctuation
exclude
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punct(text):
  return text.translate(str.maketrans('','',exclude))

# %%
text = 'Wait... what!, Are you mad???'
remove_punct(text)
# Out:
# 'Wait what Are you mad'

# %%
df['review'] = df['review'].apply(remove_punct)

# %% [markdown]
# ## Chat Conversion

# %%
chat_words = {
    'AFAIK':'As Far As I Know',
    'AFK':'Away From Keyboard',
    'ASAP':'As soon as possible',
    'ATK':'At The Keyboard',
    'ATM':'At The Moment',
    'A3':'Anytime, Anywhere, Anyhow',
    'BAK':'Back At Keyboard',
    'BBL':'Be Back Later',
    'BBS':'Be Back Soon',
    'BFN':'Bye For Now',
    'B4N':'Bye For Now',
    'BRB':'Be Right Back',
    'BRT':'Be Right There',
    'BTW':'By The Way',
    'B4':'Before',
    'B4N':'Bye For Now',
    'CU':'See You',
    'CUL8R':'See You Later',
    'CYA':'See You',
    'FAQ':'Frequently Asked Questions',
    'FC':'Fingers Crossed',
    'FWIW':'For What It\'s Worth',
    'FYI':'For Your Information',
    'GAL':'Get A Life',
    'GG':'Good Game',
    'GN':'Good Night',
    'GMTA':'Great Minds Think Alike',
    'GR8':'Great!',
    'G9':'Genius',
    'IC':'I See',
    'ICQ':'I Seek you',
    'ILU':'I Love You',
    'IMHO':'In My Honest/Humble Opinion',
    'IMO':'In My Opinion',
    'IOW':'In Other Words',
    'IRL':'In Real Life',
    'KISS':'Keep It Simple, Stupid',
    'LDR':'Long Distance Relationship'
}

# %%
def handle_chat_word(text):
  for word in text.split():
    if word.upper() in chat_words:
      text = text.replace(word,chat_words[word.upper()])
  return text

# %%
text = 'Meet me ASAP'
handle_chat_word(text)
# Out:
# 'Meet me As soon as possible'

# %%
df['review'] = df['review'].apply(handle_chat_word)

# %% [markdown]
# ## Incorrect word Handling

# %%
from textblob import TextBlob

# %%
text = 'Helllo, how are u?? This is soo beutiful'
textblb = TextBlob(text)
textblb.correct().string
# Out:
# 'Hello, how are u?? His is so beautiful'

# %% [markdown]
# ## Stopwords Removal

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
def remove_stopwords(text):
  new_text = []
  for word in text.split():
    if word in stopwords.words('english'):
      new_text.append('')
    else:
      new_text.append(word)
  x = new_text[:]
  new_text.clear()
  return " ".join(x)

# %%
text = 'Hello Dear, I am an AI Engineer, who are you?'
remove_stopwords(text)
# Out:
# 'Hello Dear, I   AI Engineer,   you?'

# %%
df['review'] = df['review'].apply(remove_stopwords)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one    reviewers  mentioned   watching  1 oz e...  positive
# 1   wonderful little production  filming techniqu...  positive
# 2   thought    wonderful way  spend time    hot s...  positive
# 3  basically theres  family   little boy jake thi...  negative
# 4  petter matteis love   time  money   visually s...  positive

# %% [markdown]
# ## Emoji Removal

# %%
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F300-\U0001F5FF"
        "\U0001F600-\U0001F64F"
        "\U0001F680-\U0001F6FF"
        "\U0001F700-\U0001F77F"
        "\U0001F780-\U0001F7FF"
        "\U0001F800-\U0001F8FF"
        "\U0001F900-\U0001F9FF"
        "\U0001FA00-\U0001FAFF"
        "\u2600-\u26FF"
        "\u2700-\u27BF"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub("", text)

# %%
text = 'Hello 👋, How are you🤔, Are you available??🙄'

remove_emojis(text)
# Out:
# 'Hello , How are you, Are you available??'

# %% [markdown]
# ## Handle Emoji Meaning

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 14.6 MB/s eta 0:00:00
# ...

# %%
import emoji

# %%
emoji.demojize('I am 🔥')
# Out:
# 'I am :fire:'

# %%
emoji.demojize('Loved it, It was so 😘')
# Out:
# 'Loved it, It was so :face_blowing_a_kiss:'

# %% [markdown]
# ## Tokenization

# %%
# Word Tokinizer
def tokenize(text):
  return re.findall(r'[\w]+', text)

# %%
text = 'I am so good!'
tokenize(text)
# Out:
# ['I', 'am', 'so', 'good']

# %%
# Sentence Tokenizer
def sen_tokenize(text):
  return re.compile(r'[.!?]').split(text)

# %%
text = 'Hello Dear, I am an AI Engineer. who are you? I am so happy for you. waht about you.'
sen_tokenize(text)
# Out:
# ['Hello Dear, I am an AI Engineer',
#  ' who are you',
#  ' I am so happy for you',
#  ' waht about you',
#  '']

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
word_tokenize(text)
# Out:
# ['Hello',
#  'Dear',
#  ',',
#  'I',
#  'am',
#  'an',
#  'AI',
#  'Engineer',
#  '.',
#  'who',
#  'are',
#  'you',
#  '?',
#  'I',
#  'am',
#  'so',
#  'happy',
#  'for',
#  'you',
#  '.',
#  'waht',
#  'about',
#  'you',
#  '.']

# %%
sent_tokenize(text)
# Out:
# ['Hello Dear, I am an AI Engineer.',
#  'who are you?',
#  'I am so happy for you.',
#  'waht about you.']

# %% [markdown]
# # Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

def stem_word(text):
  return " ".join(ps.stem(word) for word in text.split())

# %%
text = 'I am the most quickly persons in my Family, and Running too fast'

stem_word(text)
# Out:
# 'i am the most quickli person in my family, and run too fast'

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
text = 'I was running in a longest road that was too best for the jogging. after that I went to home to take breakfast and milk then  go to university where I had my too boring classes. am I interested in my classes? if I am not so why I had to go there regularly.'
punct = '?.:,!;'

sentence_words = nltk.word_tokenize(text)
print('Sentence Words:', sentence_words)

for word in sentence_words:
  if word in punct:
    sentence_words.remove(word)

print('After: ', sentence_words)
# Out:
# Sentence Words: ['I', 'was', 'running', 'in', 'a', 'longest', 'road', 'that', 'was', 'too', 'best', 'for', 'the', 'jogging', '.', 'after', 'that', 'I', 'went', 'to', 'home', 'to', 'take', 'breakfast', 'and', 'milk', 'then', 'go', 'to', 'university', 'where', 'I', 'had', 'my', 'too', 'boring', 'classes', '.', 'am', 'I', 'interested', 'in', 'my', 'classes', '?', 'if', 'I', 'am', 'not', 'so', 'why', 'I', 'had', 'to', 'go', 'there', 'regularly', '.']
# After:  ['I', 'was', 'running', 'in', 'a', 'longest', 'road', 'that', 'was', 'too', 'best', 'for', 'the', 'jogging', 'after', 'that', 'I', 'went', 'to', 'home', 'to', 'take', 'breakfast', 'and', 'milk', 'then', 'go', 'to', 'university', 'where', 'I', 'had', 'my', 'too', 'boring', 'classes', 'am', 'I', 'interested', 'in', 'my', 'classes', 'if', 'I', 'am', 'not', 'so', 'why', 'I', 'had', 'to', 'go', 'there', 'regularly']

# %%
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
  print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word, pos='v')))
# Out:
# Word                Lemma
# I                   I
# was                 be
# running             run
# in                  in
# a                   a
# longest             longest
# road                road
# that                that
# was                 be
# too                 too
# best                best
# for                 for
# the                 the
# jogging             jog
# after               after
# that                that
# I                   I
# went                go
# to                  to
# home                home
# to                  to
# take                take
# breakfast           breakfast
# and                 and
# milk                milk
# then                then
# go                  go
# to                  to
# university          university
# where               where
# I                   I
# had                 have
# my                  my
# too                 too
# boring              bore
# classes             class
# ...
